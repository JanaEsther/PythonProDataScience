# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


sns.color_palette(palette="pastel", n_colors=None, desat=None, as_cmap=True)

titanic = pd.read_csv("titanic2.csv")

# %%
titanic.head(10)
# Out:
#                                        name  gender   age class embarked  \
# 0                       Abbing, Mr. Anthony    male  42.0   3rd        S
# 1                 Abbott, Mr. Eugene Joseph    male  13.0   3rd        S
# 2               Abbott, Mr. Rossmore Edward    male  16.0   3rd        S
# 3            Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0   3rd        S
# 4               Abelseth, Miss. Karen Marie  female  16.0   3rd        S
# 5             Abelseth, Mr. Olaus Jørgensen    male  25.0   3rd        S
# 6                       Abelson, Mr. Samuel    male  30.0   2nd        C
# 7                      Abelson, Mrs. Hannah  female  28.0   2nd        C
# 8              Abī-Al-Munà, Mr. Nāsīf Qāsim    male  27.0   3rd        C
# 9  Abrahamsson, Mr. Abraham August Johannes    male  20.0   3rd        S
#
#          country   ticketno     fare  sibsp  parch survived
# 0  United States     5547.0   7.1100    0.0    0.0       no
# ...

# %%
titanic["country"].unique()
# Out:
# array(['United States', 'England', 'Norway', 'France', 'Lebanon',
#        'Finland', 'Sweden', 'Argentina', 'Canada', 'Denmark',
#        'Northern Ireland', 'Bulgaria', 'Switzerland', 'Channel Islands',
#        'Bosnia', 'Hungary', nan, 'Ireland', 'Italy', 'India', 'Wales',
#        'South Africa', 'Croatia (Modern)', 'Scotland', 'Siam', 'Uruguay',
#        'Belgium', 'Poland', 'Australia', 'Peru', 'Spain', 'Egypt',
#        'Japan', 'Syria', 'Russia', 'Slovenia', 'Greece', 'Turkey',
#        'China/Hong Kong', 'Austria', 'Latvia', 'Yugoslavia',
#        'Slovakia (Modern day)', 'Germany', 'Croatia', 'Cuba',
#        'Netherlands', 'Mexico', 'Guyana'], dtype=object)

# %%
data = [44, 45, 40, 41, 39, 42] 
keys = ['United States', 'England', 'Norway', 'France', 'Lebanon',
       'Finland', 'Sweden', 'Argentina', 'Canada', 'Denmark',
       'Northern Ireland', 'Bulgaria', 'Switzerland', 'Channel Islands',
       'Bosnia', 'Hungary','Ireland', 'Italy', 'India', 'Wales',
       'South Africa', 'Croatia (Modern)', 'Scotland', 'Siam', 'Uruguay',
       'Belgium', 'Poland', 'Australia', 'Peru', 'Spain', 'Egypt',
       'Japan', 'Syria', 'Russia', 'Slovenia', 'Greece', 'Turkey',
       'China/Hong Kong', 'Austria', 'Latvia', 'Yugoslavia',
       'Slovakia (Modern day)', 'Germany', 'Croatia', 'Cuba',
       'Netherlands', 'Mexico', 'Guyana']
# declaring exploding pie 
explode = [0, 0.1, 0, 0, 0, 0] 
# define Seaborn color palette to use 
palette_color = sns.color_palette('pastel') 
  
# plotting data on chart 
plt.pie(data, labels=keys, colors=palette_color, 
        explode=explode, autopct='%.0f%%') 
  
# displaying chart 
plt.show()

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2207 entries, 0 to 2206
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      2207 non-null   object
#  1   gender    2207 non-null   object
#  2   age       2205 non-null   float64
#  3   class     2207 non-null   object
#  4   embarked  2207 non-null   object
#  5   country   2126 non-null   object
#  6   ticketno  1316 non-null   float64
#  7   fare      1291 non-null   float64
#  8   sibsp     1307 non-null   float64
#  9   parch     1307 non-null   float64
#  10  survived  2207 non-null   object
# dtypes: float64(5), object(6)
# memory usage: 189.8+ KB

# %%
#AGE AND SEX OF THE PASSANGERS
age_sex = titanic[["age", "gender"]].value_counts()
age_sex
# Out:
# age        gender
# 30.000000  male      76
# 23.000000  male      70
# 22.000000  male      69
# 28.000000  male      68
# 25.000000  male      67
#                      ..
# 0.833333   female     1
# 0.750000   male       1
#            female     1
# 0.416667   male       1
# 74.000000  male       1
# Name: count, Length: 144, dtype: int64

# %%
girls = titanic[
(titanic["age"] < 1)&
(titanic["gender"] == "female")
]
girls
# Out:
#                                          name  gender       age class  \
# 76              Baclini, Miss. Helene Barbara  female  0.750000   3rd
# 316   Dean, Miss. Elizabeth Gladys 'Millvina'  female  0.166667   3rd
# 1269                West, Miss. Barbara Joyce  female  0.833333   2nd
#
#      embarked  country  ticketno     fare  sibsp  parch survived
# 76          C  Lebanon    2666.0  19.0502    2.0    1.0      yes
# 316         S  England    2315.0  20.1106    1.0    2.0      yes
# 1269        S  England   34651.0  27.1500    1.0    2.0      yes

# %%
babies =  titanic[titanic["age"] < 1]

babies_1st_class = titanic[(titanic["age"] < 1)&(titanic["class"] == "1st")]

babies_1st_class
# Out:
#                               name gender       age class embarked country  \
# 22  Allison, Master. Hudson Trevor   male  0.916667   1st        S  Canada
#
#     ticketno    fare  sibsp  parch survived
# 22  113781.0  151.16    1.0    2.0      yes

# %%
babies_2nd_class = titanic[(titanic["age"] < 1)&(titanic["class"] == "2nd")]
babies_2nd_class
# Out:
#                                          name  gender       age class  \
# 183             Caldwell, Master. Alden Gates    male  0.833333   2nd
# 491   Hämäläinen, Master. Viljo Unto Johannes    male  0.583333   2nd
# 1013          Richards, Master. Sibley George    male  0.750000   2nd
# 1269                West, Miss. Barbara Joyce  female  0.833333   2nd
#
#      embarked        country  ticketno   fare  sibsp  parch survived
# 183         S           Siam  248738.0  29.00    0.0    2.0      yes
# 491         S  United States  250649.0  14.10    1.0    1.0      yes
# 1013        S        England   29106.0  18.15    1.0    1.0      yes
# 1269        S        England   34651.0  27.15    1.0    2.0      yes

# %%
babies_3rd_class = titanic[(titanic["age"] < 1)&(titanic["class"] == "3rd")]
babies_3rd_class
# Out:
#                                          name  gender       age class  \
# 13                  Aks, Master. Frank Philip    male  0.833333   3rd
# 76              Baclini, Miss. Helene Barbara  female  0.750000   3rd
# 296   Danbom, Master. Gilbert Sigvard Emanuel    male  0.333333   3rd
# 316   Dean, Miss. Elizabeth Gladys 'Millvina'  female  0.166667   3rd
# 948            Peacock, Master. Albert Edward    male  0.583333   3rd
# 1182                    Tannūs, Master. As'ad    male  0.416667   3rd
#
#      embarked  country   ticketno     fare  sibsp  parch survived
# 13          S  England   392091.0   9.0700    0.0    1.0      yes
# 76          C  Lebanon     2666.0  19.0502    2.0    1.0      yes
# 296         S   Sweden   347080.0  14.0800    0.0    2.0       no
# 316         S  England     2315.0  20.1106    1.0    2.0      yes
# 948         S  England  3101315.0  13.1506    1.0    1.0       no
# 1182        C  Lebanon     2625.0   8.1004    0.0    1.0      yes

# %%
Lebanese = titanic[titanic["country"] == "Lebanon"]
Lebanese
# Out:
#                                  name  gender   age             class  \
# 8        Abī-Al-Munà, Mr. Nāsīf Qāsim    male  27.0               3rd
# 27    Al-Munà, Mr. Farīd Husayn Qāsim    male  19.0               3rd
# 64                Assaf, Mrs. Mariana  female  45.0               3rd
# 68              Attalah, Miss. Malake  female  17.0               3rd
# 72         Ayoub Daher, Miss. Banoura  female  15.0               3rd
# ...                               ...     ...   ...               ...
# 1311  Yousseff (Abi Saab), Mr. Gerios    male  26.0               3rd
# 1312   Youssiff (Sam'aan), Mr. Gerios    male  45.0               3rd
# 1313               Yūsuf, Mrs. Kātrīn  female  23.0               3rd
# 1317                Zenni, Mr. Philip    male  25.0               3rd
# 1860  Mishellany, Mr. Abraham Mansoor    male  53.0  victualling crew
#
#      embarked  country  ticketno     fare  sibsp  parch survived
# ...

# %%
Irish = titanic[titanic["country"]== "Ireland"]
Irish
# Out:
#                                name  gender   age             class embarked  \
# 91               Barry, Miss. Julia  female  30.0               3rd        Q
# 133              Bourke, Miss. Mary  female  40.0               3rd        Q
# 134                Bourke, Mr. John    male  42.0               3rd        Q
# 135          Bourke, Mrs. Catherine  female  32.0               3rd        Q
# 141    Bradley, Miss. Bridget Delia  female  22.0               3rd        Q
# ...                             ...     ...   ...               ...      ...
# 1853   Middleton, Mr. Alfred Pirrie    male  27.0  engineering crew        B
# 1999            Rogers, Mr. Michael    male  27.0  victualling crew        S
# 2125            Turley, Mr. Richard    male  37.0  engineering crew        B
# 2145         Walsh, Miss. Catherine  female  32.0  victualling crew        S
# 2180  Williamson, Mr. James Bertram    male  35.0  victualling crew        S
#
# ...

# %%
Irish_died = titanic[(titanic["country"] == "Ireland") & (titanic["survived"] == "no")]
Irish_died
# Out:
#                                name  gender   age             class embarked  \
# 91               Barry, Miss. Julia  female  30.0               3rd        Q
# 133              Bourke, Miss. Mary  female  40.0               3rd        Q
# 134                Bourke, Mr. John    male  42.0               3rd        Q
# 135          Bourke, Mrs. Catherine  female  32.0               3rd        Q
# 162        Buckley, Miss. Katherine  female  22.0               3rd        Q
# ...                             ...     ...   ...               ...      ...
# 1853   Middleton, Mr. Alfred Pirrie    male  27.0  engineering crew        B
# 1999            Rogers, Mr. Michael    male  27.0  victualling crew        S
# 2125            Turley, Mr. Richard    male  37.0  engineering crew        B
# 2145         Walsh, Miss. Catherine  female  32.0  victualling crew        S
# 2180  Williamson, Mr. James Bertram    male  35.0  victualling crew        S
#
# ...

# %%
Irish_lived = titanic[(titanic["country"]== "Ireland") & (titanic["survived"] == "yes")]
Irish_lived
# Out:
#                                      name  gender   age             class  \
# 141          Bradley, Miss. Bridget Delia  female  22.0               3rd
# 163                   Buckley, Mr. Daniel    male  21.0               3rd
# 260             Connolly, Miss. Catherine  female  23.0               3rd
# 272                     Corr, Miss. Ellen  female  16.0               3rd
# 293         Daly, Miss. Margaret Marcella  female  33.0               3rd
# 294              Daly, Mr. Eugene Patrick    male  29.0               3rd
# 330         Devaney, Miss. Margaret Delia  female  19.0               3rd
# 356               Driscoll, Miss. Bridget  female  27.0               3rd
# 451              Gilnagh, Miss. Katherine  female  17.0               3rd
# 453              Glynn, Miss. Mary Agatha  female  18.0               3rd
# 527                    Healy, Miss. Honor  female  33.0               3rd
# 604              Jermyn, Miss. Annie Jane  female  26.0               3rd
# ...

# %%
Irish_lived.shape[0]
# Out:
# 47

# %%
Irish_died.shape[0]
# Out:
# 90

# %%
sns.countplot

# %%
# AGE OF THE PASSANGERS
ages = titanic["age"]
ages
# Out:
# 0       42.0
# 1       13.0
# 2       16.0
# 3       39.0
# 4       16.0
#         ...
# 2202    41.0
# 2203    40.0
# 2204    32.0
# 2205    20.0
# 2206    26.0
# Name: age, Length: 2207, dtype: float64

# %%
sns.countplot(titanic, x="gender", hue="survived", palette="Set2")
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(titanic, y="class",hue="survived", palette="flare")
# Out:
# <Axes: xlabel='count', ylabel='class'>

# %%
titanic.tail(10)
# Out:
#                                 name gender   age             class embarked  \
# 2197     Worthman, Mr. William Henry   male  37.0  engineering crew        S
# 2198  Wrapson, Mr. Frederick Bernard   male  19.0  victualling crew        B
# 2199           Wright, Mr. Frederick   male  24.0  victualling crew        S
# 2200             Wright, Mr. William   male  40.0  victualling crew        S
# 2201         Wyeth, Mr. James Robert   male  26.0  engineering crew        S
# 2202                Wynn, Mr. Walter   male  41.0         deck crew        B
# 2203             Yearsley, Mr. Harry   male  40.0  victualling crew        S
# 2204        Young, Mr. Francis James   male  32.0  engineering crew        S
# 2205             Zanetti, Sig. Minio   male  20.0  restaurant staff        S
# 2206              Zarracchi, Sig. L.   male  26.0  restaurant staff        S
#
#       country  ticketno  fare  sibsp  parch survived
# 2197  England       NaN   NaN    NaN    NaN       no
# ...

# %%
restaurant_staff = titanic[titanic["class"]== "restaurant staff"]
restaurant_staff.shape[0]
# Out:
# 69

# %%
survivors_restaurant_staff = titanic[
(titanic["class"] =="restaurant staff")&
(titanic["survived"] == "yes")
]
survivors_restaurant_staff
# Out:
#                                          name  gender   age             class  \
# 1413               Bowker, Miss. Ruth Harwood  female  31.0  restaurant staff
# 1813               Martin, Miss. Mabel Elvina  female  20.0  restaurant staff
# 1821  Mauge, Mr. Paul Achille Maurice Germain    male  25.0  restaurant staff
#
#      embarked  country  ticketno  fare  sibsp  parch survived
# 1413        S  England       NaN   NaN    NaN    NaN      yes
# 1813        S  England       NaN   NaN    NaN    NaN      yes
# 1821        S  England       NaN   NaN    NaN    NaN      yes
